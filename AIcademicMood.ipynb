# %% [markdown]
# <a href="https://colab.research.google.com/github/guptanmol02/-AIcademic-Mood-prediction/blob/main/AIcademicMood.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# About the dataset
# text: how person is feeling currently
# Mood: person's mood

# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# printing the stopwords in english
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %% [markdown]
# Data Preprocessing

# %%
#loading the dataset in pandas dataframe
mood_dataset =pd.read_csv('/content/mood_dataset_3000.csv')

# %%
mood_dataset.shape
# Out:
# (3000, 2)

# %%
#print first 5 rows of the dataset
mood_dataset.head()
# Out:
#                                                 text     mood
# 0           This is a very happy day, truly amazing.    happy
# 1  My day has been depressed; everything feels un...      sad
# 2                      I feel yay and smiling today.    happy
# 3         This is a very joyful day, truly grateful.    happy
# 4    My day has been alright; everything feels okay.  neutral

# %%
#counting the number of missing values in the dataset
mood_dataset.isnull().sum()
# Out:
# text    0
# mood    0
# dtype: int64

# %%
#merging the text and mood
mood_dataset['text']=mood_dataset['text']+' '+mood_dataset['mood']
print(mood_dataset['text'])

# %% [markdown]
# Stemming: It is the process of reducing a word to its root word

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
  stemmed_content = re.sub('[^a-zA-Z]',' ',content)
  stemmed_content = stemmed_content.lower()
  stemmed_content = stemmed_content.split()
  stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
  stemmed_content = ' '.join(stemmed_content)
  return stemmed_content

# %%
mood_dataset['text'] = mood_dataset['text'].apply(stemming)

# %%
print(mood_dataset['text'])
# Out:
# 0                      happi day truli amaz
# 1          day depress everyth feel unhappi
# 2                      feel yay smile today
# 3                       joy day truli grate
# 4             day alright everyth feel okay
#                        ...
# 2995           day normal everyth feel noth
# 2996          day mad everyth feel frustrat
# 2997                feel typic routin today
# 2998                  happi day truli excit
# 2999    anoth day kind joy mayb littl great
# Name: text, Length: 3000, dtype: object

# %%
#seperating text and mood
X = mood_dataset['text'].values
Y = mood_dataset['mood'].values

# %%
print(X)
# Out:
# ['happi day truli amaz' 'day depress everyth feel unhappi'
#  'feel yay smile today' ... 'feel typic routin today'
#  'happi day truli excit' 'anoth day kind joy mayb littl great']

# %%
print(Y)
# Out:
# ['happy' 'sad' 'happy' ... 'neutral' 'happy' 'happy']

# %%
#converting the textual data to numerical data
vectorizer = TfidfVectorizer()
vectorizer.fit(X)

X = vectorizer.transform(X)
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 15366 stored elements and shape (3000, 59)>
#   Coords	Values
#   (0, 2)	0.6273928460680752
#   (0, 12)	0.22430625125115677
#   (0, 25)	0.6371387466546637
#   (0, 49)	0.38745211299408044
#   (1, 12)	0.2168472543593935
#   (1, 13)	0.6286541399723654
#   (1, 15)	0.38822612014728836
#   (1, 18)	0.22322891128328556
#   (1, 52)	0.59767932319519
#   (2, 18)	0.22896997930698434
#   (2, 45)	0.620963357808446
#   (2, 48)	0.38685154424719603
#   (2, 57)	0.6421239284974348
#   (3, 12)	0.2245025427294287
#   (3, 23)	0.630322106069086
#   (3, 30)	0.6339642388347513
#   (3, 49)	0.3877911741998871
#   (4, 0)	0.604958096795825
#   (4, 12)	0.21423074466321743
#   (4, 15)	0.3835417287738534
#   (4, 18)	0.22053539961044918
#   (4, 39)	0.6264110223886868
#   (5, 12)	0.22461707467813202
#   (5, 28)	0.6392870687258647
#   (5, 47)	0.6247589472745971
#   :	:
#   (2995, 12)	0.21127959719606534
#   (2995, 15)	0.3782582284844926
# ...

# %%
#splitting the dataset to train and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify=Y, random_state=2)

# %% [markdown]
# Training the model:
# Logistic Regression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluate accuraacy store

# %%
# accuracy score in the training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  1.0

# %%
# accuracy score in the test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  1.0

# %% [markdown]
# Making a predictive system

# %%
# Taking input from the user
input_text = input("Enter the text: ")

# Define the stemming function if it's not already defined
if 'stemming' not in globals():
    import re
    from nltk.corpus import stopwords
    from nltk.stem.porter import PorterStemmer
    import nltk
    try:
        stopwords.words('english')
    except LookupError:
        nltk.download('stopwords')
    port_stem = PorterStemmer()

    def stemming(content):
        stemmed_content = re.sub('[^a-zA-Z]',' ',content)
        stemmed_content = stemmed_content.lower()
        stemmed_content = stemmed_content.split()
        stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
        stemmed_content = ' '.join(stemmed_content)
        return stemmed_content

# Preprocess the input text
stemmed_input_text = stemming(input_text)

# Transform the preprocessed text using the trained vectorizer
input_data_features = vectorizer.transform([stemmed_input_text])

# Predict the mood using the trained model
prediction = model.predict(input_data_features)

# Output the predicted mood
predicted_mood = prediction[0]
print("Predicted Mood:", predicted_mood)
# Assuming mood_messages is a dictionary mapping moods to messages, replace with your actual dictionary or remove this line if not needed.
# print(mood_messages.get(predicted_mood, f" The person is feeling {predicted_mood}."))
# Out:
# Enter the text: i am feeling hungry
# Predicted Mood: sad

# %%
# Vectorize the input text
input_text_vector = vectorizer.transform([stemmed_input_text])

# Vectorize the dataset texts
dataset_vectors = vectorizer.transform(mood_dataset['text'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity between the input text and all dataset texts
cosine_similarities = cosine_similarity(input_text_vector, dataset_vectors)

# %%
# Get the indices of the most similar texts
# We use [0] because cosine_similarities is a 2D array with one row
most_similar_indices = cosine_similarities[0].argsort()[::-1]

# Print the most similar texts and their moods
print("Most similar texts and their moods:")
for i in most_similar_indices[:5]: # Display top 5 most similar texts
    print(f"Similarity: {cosine_similarities[0][i]:.4f} - Text: {mood_dataset['text'][i]} - Mood: {mood_dataset['mood'][i]}")
# Out:
# Most similar texts and their moods:
# Similarity: 0.3012 - Text: feel unhappi today - Mood: sad
# Similarity: 0.3012 - Text: feel unhappi today - Mood: sad
# Similarity: 0.3001 - Text: feel blue today - Mood: sad
# Similarity: 0.2994 - Text: feel tire today - Mood: sad
# Similarity: 0.2994 - Text: feel tire today - Mood: sad
